# %% [raw]
# ---
# layout: post
# title: Trimester 1 Reflection
# date: 2025-11-06
# description: A final reflection on the first trimester of CSP
# type: ccc
# courses: {}
# toc: true
# comments: true
# permalink: /trireflection/
# author: Adhav Selvan
# ---

# %% [markdown]
# # Trimester 1 Final Review Blog

# %% [markdown]
# ## Trimester Progress

# %% [markdown]
# While this trimester has been nothing short of hectic, it sure has been a long way from when I first came into the classroom knowing nothing but the print function in python.  From getting my tools set up, to teaching the class about the importace of lists in JavaScript & Python, CSP Trimester 1 has really taught me a lot about a potential future for me in CS.

# %% [markdown]
# ## Key Points from Sprints
#
# ### Tools Setup
# - Through this sprint, I understood the basics of Computer Science, and made sense of the basic tools and programs that would be used in the course
# - Despite positive expectations, the setup of tools on their own was quite difficult, and took much longer than expected
# - While the effects were not immidiate, this setup helped me troubleshoot technical issues that cropped out throughout the trimester
#
# ### Lessons in basics of Python & Javascript
# - Through this sprint, I made sense of the basics of the coding languages through the student led lessons
# - The homework provided throughout the lessons helped incorporate a better understanding to assist in a better learning of the concepts
# - By also teaching a lesson, I was able to undestand both sides of the coin well, with experience as a teacher also assiting with the learning of the topic
#
# ### N@TM Project
# - Through the project, more than technical skills, technical collaboration was an important takeaway for me
# - By working with many people to create a project worthy of display to an audience, I used valuable skills in managing time and dividing tasks to create a better project
# - By presenting the project to people with technical backgrounds, it was valuable to recieve valuble insight and comments on our work, and how we could improve
# - Through the feedback that we receieved, such as question on how the UI worked, and what code we used, we recieved a greater understanding in our own project by answering such questions that otherwise would have not been recognized

# %% [markdown]
# ## What next?
#
# After learning much of the basics this trimester, next trimester, I hope to work on something that could help students further.  Once thing I had in mind was to create a database of templates that can be used to help create better projects for students.  Some templates could include blog templates for purposes that are required students, and lessons & hw templates.  One issue I ran into this trimester involved the incostinecy between lessons and homeworks, as some lessons were overly complicated and detailed for the material, while some were so sparsely detailed that comleting the homeworks with the given information was a challange.  By giving a universal template, a greater uniformity can be achieved between homeworks and lessons, resulting in greater understand for the teachers and students.

# %% [markdown]
# ## Analytics
#
# Through this trimester, through the countless commits and code fixes I have done, much has been completed and worked on to come to this point.  Many of the commits are quite small, containing small changes.  This occured because when I was attempting to submit the homeworks, I ran into multiple issues, resulting in the commit-happy fervor.  In the end, it was CSA student Xavier Thompson who helped me fix everything.

# %% [markdown]
# ## MCQ review
# Through the MCQ, which I got 34/66 on, I realised that there were many areas I needed work on.  These include:
# From Chapter 3:
# - Boolean Expressions
# - Conditionals
# - Iterations
# - Developing Algorithims
# - Calling Procedures
# - Random Values
# - Algorithmic Efficiency
# To help me understand these concepts, I will go back and watch the videos under each sections.  Will also work on W3Schools material that corresponds to these concepts, and revise the topics.
